# %%
import pandas as pd

df = pd.read_csv('C:/Users/muham/OneDrive/Documents/GitHub/lendingclub-cleaning-project/data/lendingData.csv')

print(df.shape)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10132\3894295200.py:3: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/muham/OneDrive/Documents/GitHub/lendingclub-cleaning-project/data/lendingData.csv')
# (2260701, 151)

# %%
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
df.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# ...

# %%
#drop all empty columns
df.dropna(axis=1, how='all', inplace=True)

# %%
#drop all columns 90% empty
nulls = df.isnull().sum() / len(df)
high_nulls = nulls[nulls > 0.9]
df.drop(columns=high_nulls.index, inplace=True)

# %%
#Fill numerical columns with median
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
#Fill categorical columns with mode
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_10132\3012995258.py:3: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])

# %%
#Remove duplicate rows
df.drop_duplicates(inplace=True)
#Fix column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# Drop irrelevant columns
cols_to_drop = ['id', 'member_id', 'url', 'emp_title', 'desc', 'title']
df.drop(columns=cols_to_drop, inplace=True, errors='ignore')

# %%
print(df.shape)
df.info()
df.describe()
# Out:
# (2260701, 109)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 109 entries, loan_amnt to debt_settlement_flag
# dtypes: float64(88), object(21)
# memory usage: 1.8+ GB
#           loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count  2.260701e+06  2.260701e+06     2.260701e+06  2.260701e+06
# mean   1.504690e+04  1.504163e+04     1.502341e+04  1.309282e+01
# std    9.190182e+03  9.188350e+03     9.192269e+03  4.832103e+00
# min    5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%    8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%    1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%    2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max    4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260701e+06  2.260701e+06  2.260701e+06  2.260701e+06    2.260701e+06
# ...

# %%
df.to_csv(r'C:\Users\muham\OneDrive\Documents\GitHub\lendingclub-cleaning-project\data\lendingData_clean.csv', index=False)
